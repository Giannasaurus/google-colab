# %% [markdown]
# # A Quick Tour of Python Language Syntax

# %%
1 + 2
# Out:
# 3

# %%
print("hello") #this is output statement syntax
# Out:
# hello

# %%
a = 5
b = 5
print (a)
print (b)
# Out:
# 5
# 5

# %%
a = "hello world" # str
b = 20 #int
c= 20.5 #float
d = ["one","two","three"] #list
e = {"name":"jerome","age":"40"} #dict

# %%
#string slice
a = "jerome"
print(a[:4])
# Out:
# jero

# %%
#string cases
a = "jerome"
print(a.upper())
print(a.lower())
# Out:
# JEROME
# jerome

# %%
#string concatenation
a = "dog"
b = "cat"
c = a + b
print(c)


a = "dog"
b = "cat"
c = a +"  " +b
print(c)
# Out:
# dogcat
# dog  cat

# %%
#boolean

print(10>9)
print(10==9)
print(10<9)

a = 200
b = 20

if b>a:
    print("b is greater than")
else:
    print("b is not greater than")
# Out:
# True
# False
# False
# b is not greater than

# %%
x = 1 + 2 + 3 + 4 + \
    5 + 6 + 7 + 8

# %%
x = (1 + 2 + 3 + 4 +
     5 + 6 + 7 + 8)

# %%
x=1+2
x = 1 + 2
x             =        1    +                2

# %%
2 * (3 + 4)
# Out:
# 14

# %%
print('first value: ', x)
# Out:
# first value:  3

# %%
print('second value:', 2)
# Out:
# second value: 2

# %%
L = [4,2,3,1]
L.sort()
print(L)
# Out:
# [1, 2, 3, 4]

# %%
print 'Hello'
# Out:
#   Input In [8]
#     print 'Hello'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("hello")
# Out:
# hello

# %%
a= 1
b = 2
(a+b)
# Out:
# 3

# %%
# Out:
#   File "<tokenize>", line 11
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# <a href="https://colab.research.google.com/github/Giannasaurus/google-colab/blob/main/a_i_dual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Output statement example

# %%
print("hello") #output statement
# Out:
# hello

# %%
x = 10 # x is equal to 10
y = 1.11 # y is 1.11
name = "mark" #name is equals to string value mark
a,b,c = "dog","cat","rat" # multiple assignmen for variables
d,e = "rat",21 #assigning values for different data type
f1 = f2 = f3 = "apple" # multiple assignment for different variable names
print(f1,f2,f3)
print(a,b,c)
print(d,e)
print(a)
print(b)
print(c)
print(name)
print (x)
# Out:
# dog cat rat
# rat 21
# dog
# cat
# rat
# mark
# 10

# %%
values = ["hey" , "hello","bro"]
a ,b ,c = values
print(a)
print(b)
print(c)
print(a,b,c)
print(a + b +c)
# Out:
# hey
# hello
# bro
# hey hello bro
# heyhellobro

# %% [markdown]
# String in python

# %%
a = "hello"
print(a[0]) #access sting value
print(len(a)) # to check length of the string
for b in "dog": #iteration on string value
  print(b)
# Out:
# h
# 5
# d
# o
# g

# %% [markdown]
# String modification

# %%
a="hello"
b = " WORLD, bro"
print(a.upper())
print(b.lower())
print(b.strip())
print(a.replace("h","j"))
# Out:
# HELLO
#  world, bro
# WORLD, bro
# jello
